# %%
# Madhur Gupta
# Exp 2: Study of list in python

# %%
list1=["apple","banana","orange",]
print(list1)
# Out:
# ['apple', 'banana', 'orange']

# %%
list2=["apple","banana","orange",1,2,3,4,True]
print(list2)
# Out:
# ['apple', 'banana', 'orange', 1, 2, 3, 4, True]

# %%
list3=["apple","banana","banana","apple"]
print(list3)
# Out:
# ['apple', 'banana', 'banana', 'apple']

# %%
list4=["apple","banaana","banana","apple","orange","cheery"]
print(list4[1])
print(list4[-4])
print(list4[2:5])
print(list4[:4])
print(list4[2:])
# Out:
# banaana
# banana
# ['banana', 'apple', 'orange']
# ['apple', 'banaana', 'banana', 'apple']
# ['banana', 'apple', 'orange', 'cheery']

# %%
list5=["apple","orange","mango"]
list5[1]=2
print(list5)
# Out:
# ['apple', 2, 'mango']

# %%
list6=["apple","orange","mango"]
list6.append(3)
print(list6)
# Out:
# ['apple', 'orange', 'mango', 3]

# %%
list7=["apple","orange","mango"]
list7.insert(1,"go")
print(list7)
# Out:
# ['apple', 'go', 'orange', 'mango']

# %%
list8=["apple","orange","mango"]
list9=["go","hi"]
list8.extend(list9)
print(list8)
# Out:
# ['apple', 'orange', 'mango', 'go', 'hi']

# %%
#task 1
mark=[90,82,66,76,33]
print(len(mark))
print(min(mark))
print(max(mark))
print(sum(mark))
print(sum(mark)/len(mark))
print(sorted(mark))
mark.sort()
print(mark)
# Out:
# 5
# 33
# 90
# 347
# 69.4
# [33, 66, 76, 82, 90]
# [33, 66, 76, 82, 90]

# %%
# task 2
grocery=["milk","egg","water","sugar","tea","biscuit","potato"]
(grocery.append("mango"))
print(grocery)
grocery.remove("milk")
print(grocery)
grocery.remove("egg")
print(grocery)
# Out:
# ['milk', 'egg', 'water', 'sugar', 'tea', 'biscuit', 'potato', 'mango']
# ['egg', 'water', 'sugar', 'tea', 'biscuit', 'potato', 'mango']
# ['water', 'sugar', 'tea', 'biscuit', 'potato', 'mango']
